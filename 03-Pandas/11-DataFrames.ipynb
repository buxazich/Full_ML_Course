# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA', 'NY', 'AZ', 'TX']
mycol = ['January','February','March']
df = pd.DataFrame(mydata, index=myindex, columns=mycol)
df
# Out:
#     January  February  March
# CA       95        11     81
# NY       70        63     87
# AZ       75         9     77
# TX       40         4     63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   January   4 non-null      int64
#  1   February  4 non-null      int64
#  2   March     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
# где мой блокнот?
# %pwd
# Out:
# '/Users/user/ML Python/03-Pandas'

# %%
# %ls
# Out:
# 00-SPractice.ipynb
# 00-Series.ipynb*
# 01-DPractice.ipynb
# 01-DataFrames.ipynb*
# 02-Conditional-Filtering.ipynb*
# 03-Useful-Methods.ipynb*
# 04-Missing-Data.ipynb*
# 05-Groupby-Operations-and-MultiIndex.ipynb*
# 06-Combining-DataFrames.ipynb*
# 07-Text-Methods.ipynb*
# 08-Time-Methods.ipynb*
# 09-Inputs-and-Outputs.ipynb*
# 10-Pivot-Tables.ipynb*
# 11-Pandas-Project-Exercise.ipynb*
# 12-Pandas-Project-Exercise-Solution.ipynb*
# RetailSales_BeerWineLiquor.csv*
# Sales_Funnel_CRM.csv*
# __pycache__/
# example.csv*
# example.xlsx*
# hotel_booking_data.csv*
# movie_scores.csv*
# mpg.csv*
# my_excel_file.xlsx*
# new_file.csv*
# new_workbook.xlsx*
# newfile.csv*
# reshaping_pivot.png*
# sample_table.html*
# simple.html*
# tips.csv*

# %%
df = pd.read_csv('/Users/user/ML Python/03-Pandas/tips.csv')
df = pd.read_csv('tips.csv') # либо так

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
# Первые строки
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
# Последние строки
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
# мин, макс, среднее следующим методом
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
print(type(df))
print(type(df['total_bill']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
mycols = ['total_bill','tip']
df[mycols]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
a = df[['total_bill','tip']]
a
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
# добавление новой колонки
df['tip_percentage'] = 100 * df['tip'] / df['total_bill']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df['price_per_person'] = np.round(df['price_per_person'],1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.5
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.4
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              11.8
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.2
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
# Inplace=True - внесет изменения в оригинальный датафрейм
df.drop('tip_percentage',axis=1,)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2               8.5
# 1         10.34  1.66    Male     No   Sun  Dinner     3               3.4
# 2         21.01  3.50    Male     No   Sun  Dinner     3               7.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2              11.8
# 4         24.59  3.61  Female     No   Sun  Dinner     4               6.2
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3               9.7
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2              13.6
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2              11.3
# 242       17.82  1.75    Male     No   Sat  Dinner     2               8.9
# 243       18.78  3.00  Female     No  Thur  Dinner     2               9.4
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2               8.5
# 1         10.34  1.66    Male     No   Sun  Dinner     3               3.4
# 2         21.01  3.50    Male     No   Sun  Dinner     3               7.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2              11.8
# 4         24.59  3.61  Female     No   Sun  Dinner     4               6.2
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3               9.7
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2              13.6
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2              11.3
# 242       17.82  1.75    Male     No   Sat  Dinner     2               8.9
# 243       18.78  3.00  Female     No  Thur  Dinner     2               9.4
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
df = df.drop('tip_percentage', axis=1) # удалит колонку в оригинальном датасете.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.5
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.4
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              11.8
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.2
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.shape
# Out:
# (244, 11)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
# В качестве индекса можно поставить любую колонку (желательно уникальную). 
df = df.set_index('Payment ID')

# %%
# чтобы вернуть все как было. 
df.reset_index()
# Out:
#      index  total_bill   tip     sex smoker   day    time  size  \
# 0        0       16.99  1.01  Female     No   Sun  Dinner     2
# 1        1       10.34  1.66    Male     No   Sun  Dinner     3
# 2        2       21.01  3.50    Male     No   Sun  Dinner     3
# 3        3       23.68  3.31    Male     No   Sun  Dinner     2
# 4        4       24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...         ...   ...     ...    ...   ...     ...   ...
# 239    239       29.03  5.92    Male     No   Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242    242       17.82  1.75    Male     No   Sat  Dinner     2
# 243    243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 0                 8.5  Christy Cunningham  3560325168603410    Sun2959
# ...

# %%
# получаем строки (на основе числового индекса).
df.iloc[0] # interger based location
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                   8.5
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# на основе именного индекса.
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                   8.5
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# получаем несколько строк.
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.5  Christy Cunningham  3560325168603410
# Sun4608                  3.4      Douglas Tucker  4478071379779230
# Sun4458                  7.0      Travis Walters  6011812112971322
# Sun5260                 11.8    Nathaniel Harris  4676137647685994

# %%
df.loc[['Sun2959','Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.5  Christy Cunningham  3560325168603410
# Sun5260                 11.8    Nathaniel Harris  4676137647685994

# %%
# удаление строк
df.drop('Sun2959', axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                  3.4    Douglas Tucker  4478071379779230
# ...

# %%
# df = df.iloc[1:], другой способ удалить определенную строку.

# %%
# добвление строк. 
one_row = df.iloc[0]
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                   8.5
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
pd.concat([df, pd.DataFrame([one_row])])
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ...             ...   ...     ...    ...   ...     ...   ...
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#          price_per_person          Payer Name         CC Number
# Sun2959               8.5  Christy Cunningham  3560325168603410
# Sun4608               3.4      Douglas Tucker  4478071379779230
# ...
