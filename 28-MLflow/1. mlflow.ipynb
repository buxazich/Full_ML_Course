# %%
import mlflow
import mlflow.sklearn

import pandas as pd
import numpy as np

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

# 1. Загружаем данные
data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# 2. Параметры модели
params = {
    "n_estimators": 200,
    "max_depth": 5,
    "random_state": 42
}

# 3. Указываем эксперимент
mlflow.set_experiment("breast_cancer_rf")

# 4. Запускаем run
with mlflow.start_run():

    # логируем параметры
    mlflow.log_params(params)

    # 5. Обучаем модель
    model = RandomForestClassifier(**params)
    model.fit(X_train, y_train)

    # 6. Предсказания
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]

    # 7. Метрики
    acc = accuracy_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_proba)

    mlflow.log_metric("accuracy", acc)
    mlflow.log_metric("roc_auc", auc)

    # 8. Логируем модель
    mlflow.sklearn.log_model(
        model,
        artifact_path="model"
    )

    print(f"Accuracy: {acc:.4f}")
    print(f"ROC AUC:  {auc:.4f}")
# Out:
# 2026/02/18 16:07:14 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/02/18 16:07:14 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/02/18 16:07:14 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/02/18 16:07:14 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/02/18 16:07:14 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/02/18 16:07:14 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/02/18 16:07:14 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/02/18 16:07:14 INFO mlflow.store.db.utils: Updating database tables
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# 2026/02/18 16:07:14 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Running upgrade 1bd49d398cd23 -> b7c8d9e0f1a2, add trace metrics table
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Running upgrade b7c8d9e0f1a2 -> 5d2d30f0abce, update job table
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Running upgrade 5d2d30f0abce -> c9d4e5f6a7b8, add routing strategy to endpoints and linkage type to mappings
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Running upgrade c9d4e5f6a7b8 -> 2c33131f4dae, add online_scoring_configs table
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Running upgrade 2c33131f4dae -> d3e4f5a6b7c8, add display_name to endpoint_bindings
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/18 16:07:15 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/02/18 16:07:15 INFO mlflow.tracking.fluent: Experiment with name 'breast_cancer_rf' does not exist. Creating a new experiment.
# 2026/02/18 16:07:15 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /Users/user/Full_ML_Course/.venv/lib/python3.12/site-packages/mlflow/models/model.py:1209: FutureWarning: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is the 'skops' format.
#   flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# Accuracy: 0.9650
# ROC AUC:  0.9967

# %%
# !mlflow ui
# Out:
# Backend store URI not provided. Using sqlite:///mlflow.db
# Registry store URI not provided. Using backend store URI.
# 2026/02/18 16:09:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/02/18 16:09:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/02/18 16:09:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/02/18 16:09:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/02/18 16:09:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/02/18 16:09:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/02/18 16:09:20 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/18 16:09:20 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# ERROR:    [Errno 48] Address already in use
